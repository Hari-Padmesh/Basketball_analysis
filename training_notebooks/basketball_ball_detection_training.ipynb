# %%
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="S6wcIjhiCPoUWuFr4Ud1")
project = rf.workspace("workspace-5ujvu").project("basketball-players-fy4c2-vfsuv")
version = project.version(17)
dataset = version.download("yolov5")
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Basketball-Players-17 in yolov5pytorch:: 100%|██████████| 652/652 [00:00<00:00, 936.89it/s]

# %%
import os

# Check dataset location and contents
print(f"Dataset location: {dataset.location}")
print(f"\nContents of dataset location:")
for item in os.listdir(dataset.location):
    item_path = os.path.join(dataset.location, item)
    print(f"  {'[DIR]' if os.path.isdir(item_path) else '[FILE]'} {item}")
    
# Check if data.yaml exists
data_yaml_path = f"{dataset.location}/data.yaml"
print(f"\ndata.yaml exists at {data_yaml_path}: {os.path.exists(data_yaml_path)}")

# Check for data.yaml in subdirectories
for root, dirs, files in os.walk(dataset.location):
    if "data.yaml" in files:
        print(f"Found data.yaml at: {os.path.join(root, 'data.yaml')}")
# Out:
# Dataset location: d:\Basketball_analysis\training_notebooks\Basketball-Players-17
#
# Contents of dataset location:
#   [DIR] Basketball-Players-17
#
# data.yaml exists at d:\Basketball_analysis\training_notebooks\Basketball-Players-17/data.yaml: False

# %% [markdown]
# # Train Yolo

# %%
import shutil
shutil.move("Basketball-Players-17/train","Basketball-Players-17/Basketball-Players-17/train")
shutil.move("Basketball-Players-17/valid","Basketball-Players-17/Basketball-Players-17/valid")
# Out:
# 'Basketball-Players-17/Basketball-Players-17/valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=250 imgsz=640 plots=True batch=8
# Out:
# ^C
